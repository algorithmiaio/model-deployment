# %% [markdown]
# # STEP 1: Installing Required Software
#
# We need to make the following software available on your computer:
# * gcloud: access to Google’s cloud services
# * kubectl: controlling a Kubernetes cluster
# * kustomize: a helper tool that makes it easier to modify kubernetes jobs
# * kfctl: controlling Kubeflow specifically
#
# This tutorial is largely based on [Google's end-to-end Kubeflow tutorial](https://www.kubeflow.org/docs/gke/gcp-e2e/).

# %% [markdown]
# ## Gcloud, Kubectl and kusomize
# Unfortunately you cannot install gcloud through Jupyter.  If you are on a Mac you will have to run the following from the command shell to instal gcloud:
# ```
# curl https://sdk.cloud.google.com | bash  # install gcloud
# exec -l $SHELL  # restart the shell
# gcloud init
# ```
# If you are not on a Mac check out instructions for other systems [here](https://cloud.google.com/sdk/docs/downloads-interactive).
#
# Once you have  gcloud installed you can install kubectl and kustomize like this (again, on a Mac):
# ```
# gcloud components install kubectl
# brew install kustomize
# ```

# %% [markdown]
# ## kfctl
# We don’t “install” kfctl exactly - we just download the executable and put it in a place we can reference.  Download the appropriate version from the [Kubeflow releases page](https://github.com/kubeflow/kubeflow/releases/) into the directory of your choice, unzip it, and then put it on your path.  Example commands (in this case just putting it in the working directory) are:

# %%
# %%capture
# !wget https://github.com/kubeflow/kubeflow/releases/download/v0.5.1/kfctl_v0.5.1_darwin.tar.gz
# !tar -xvf kfctl_v0.5.1_darwin.tar.gz

# %% [markdown]
# # STEP 2: Creating the Project
# Google Cloud divides things into "projects" that can have multiple resources assocaited with them.  If you already have a project you can just use it.  In this section we will create a new project and configure gcloud to point to it.

# %% [markdown]
# First use gcloud to tell Google who you are and associate all of this with your google email address.  This command will open up a browser window where you can log in:

# %%
# %%capture
# !gcloud auth application-default login

# %% [markdown]
# Then go to the [Google Cloud console page](https://console.cloud.google.com), create a project, and get its ID.  Also **make sure billing is enabled for it**, and choose a geographical region and zone for the project.  Set those decisions as python variables:

# %%
PROJECT='kubeflow-245520'
REGION='us-west2'
ZONE='us-west2-c'

# %% [markdown]
# Then configure gcloud to point to that project and zone:

# %%
# !gcloud config set project $PROJECT
# !gcloud config set compute/zone $ZONE
# Out:
# Updated property [core/project].
# Updated property [compute/zone].

# %% [markdown]
# # STEP 3: Create GKE Cluster
# Now we will create a Google Kubernetes Engine (GKE) cluster, under the umbrella of the current project, that has kubeflow running on it.
#
# Choose a name for the Kubernetes cluster to use, a name for the GCloud deployment, and login credentials for the web UI of the cluster:

# %%
KFAPP='kfapp2'
KUBEFLOW_USERNAME='fcady'
KUBEFLOW_PASSWORD='mypass'

# %% [markdown]
# Use kfctl to create the cluster (and a directory of the same name on your local box) and set up its configurations (this will fail if you don’t have billing enabled).  This process will take a while (maybe 20 minutes?) as the resources for the cluster get provisioned.

# %%
# %env KUBEFLOW_USERNAME=$KUBEFLOW_USERNAME
# %env KUBEFLOW_PASSWORD=$KUBEFLOW_PASSWORD
# !./kfctl init $KFAPP --platform gcp --project $PROJECT --use_basic_auth -V
# %cd $KFAPP
# !../kfctl generate all -V --zone $ZONE
# !../kfctl apply all -V
# Out:
# [Errno 2] No such file or directory: 'kfapp2'
# /Users/fieldcady/Desktop/kube/kfapp2
# INFO[0000] reading from /Users/fieldcady/Desktop/kube/kfapp2/app.yaml  filename="coordinator/coordinator.go:341"
# WARN[0000]
# ****************************************************************
# Notice anonymous usage reporting enabled using spartakus
# To disable it
# If you have already deployed it run the following commands:
#   cd $(pwd)
#   ks delete default -c spartakus
#   kubectl -n ${K8S_NAMESPACE} delete deploy -l app=spartakus
#
# Then run the following command to remove it from your ksonnet app:
#   ks component rm spartakus
#
# For more info: https://www.kubeflow.org/docs/guides/usage-reporting/
# ****************************************************************
#   filename="coordinator/coordinator.go:242"
# INFO[0000] Setting acmeEmail to fcady@algorithmia.io     filename="gcp/gcp.go:1027"
# INFO[0000] Setting ipName to kfapp2-ip                   filename="gcp/gcp.go:1027"
# INFO[0000] Setting hostname to kfapp2.endpoints.kubeflow-245520.cloud.goog  filename="gcp/gcp.go:1027"
# INFO[0000] Setting mysqlPd to kfapp2-storage-metadata-store  filename="gcp/gcp.go:1027"
# INFO[0000] Setting minioPd to kfapp2-storage-artifact-store  filename="gcp/gcp.go:1027"
# INFO[0000] Setting injectGcpCredentials to true          filename="gcp/gcp.go:1027"
# INFO[0000] Setting usageId to 7377553633814356386        filename="gcp/gcp.go:1027"
# INFO[0000] reading from /Users/fieldcady/Desktop/kube/kfapp2/app.yaml  filename="coordinator/coordinator.go:341"
# INFO[0000] Ksonnet.Generate Name kfapp2 AppDir /Users/fieldcady/Desktop/kube/kfapp2 Platform gcp  filename="ksonnet/ksonnet.go:369"
# INFO[0000] Creating environment "default" with namespace "kubeflow", pointing to "file:/Users/fieldcady/Desktop/kube/kfapp2/.cache/v0.5.1/bootstrap/k8sSpec/v1.11.7/api/openapi-spec/swagger.json" cluster at address "127.0.0.1"  filename="env/create.go:77"
# INFO[0002] Generating ksonnet-lib data at path '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/lib/ksonnet-lib/v1.11.7'  filename="lib/lib.go:148"
# INFO[0002] Successfully initialized the app kfapp2.      filename="ksonnet/ksonnet.go:505"
# INFO[0002] App kfapp2 add registry kubeflow URI /Users/fieldcady/Desktop/kube/kfapp2/.cache/v0.5.1/kubeflow  filename="ksonnet/ksonnet.go:621"
# INFO[0002] Retrieved 6 files                             filename="registry/cache.go:114"
# INFO[0002] Retrieved 22 files                            filename="registry/cache.go:114"
# INFO[0002] Retrieved 9 files                             filename="registry/cache.go:114"
# INFO[0002] Retrieved 35 files                            filename="registry/cache.go:114"
# INFO[0002] Retrieved 49 files                            filename="registry/cache.go:114"
# INFO[0002] Retrieved 6 files                             filename="registry/cache.go:114"
# INFO[0002] Retrieved 4 files                             filename="registry/cache.go:114"
# INFO[0002] Retrieved 4 files                             filename="registry/cache.go:114"
# INFO[0002] Retrieved 9 files                             filename="registry/cache.go:114"
# INFO[0002] Retrieved 14 files                            filename="registry/cache.go:114"
# INFO[0002] Retrieved 6 files                             filename="registry/cache.go:114"
# INFO[0002] Retrieved 17 files                            filename="registry/cache.go:114"
# INFO[0002] Retrieved 8 files                             filename="registry/cache.go:114"
# INFO[0002] Retrieved 12 files                            filename="registry/cache.go:114"
# INFO[0002] Retrieved 4 files                             filename="registry/cache.go:114"
# INFO[0002] Creating Component: ambassador ...            filename="ksonnet/ksonnet.go:207"
# INFO[0002] Args: [ambassador ambassador]                 filename="ksonnet/ksonnet.go:208"
# INFO[0002] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/ambassador.jsonnet'  filename="component/create.go:92"
# INFO[0002] Creating Component: argo ...                  filename="ksonnet/ksonnet.go:207"
# INFO[0002] Args: [argo argo]                             filename="ksonnet/ksonnet.go:208"
# INFO[0002] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/argo.jsonnet'  filename="component/create.go:92"
# INFO[0002] Creating Component: basic-auth ...            filename="ksonnet/ksonnet.go:207"
# INFO[0002] Args: [basic-auth basic-auth]                 filename="ksonnet/ksonnet.go:208"
# INFO[0002] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/basic-auth.jsonnet'  filename="component/create.go:92"
# INFO[0002] Creating Component: basic-auth-ingress ...    filename="ksonnet/ksonnet.go:207"
# INFO[0002] Args: [basic-auth-ingress basic-auth-ingress --ipName kfapp2-ip --hostname kfapp2.endpoints.kubeflow-245520.cloud.goog]  filename="ksonnet/ksonnet.go:208"
# INFO[0002] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/basic-auth-ingress.jsonnet'  filename="component/create.go:92"
# INFO[0002] Creating Component: centraldashboard ...      filename="ksonnet/ksonnet.go:207"
# INFO[0002] Args: [centraldashboard centraldashboard]     filename="ksonnet/ksonnet.go:208"
# INFO[0002] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/centraldashboard.jsonnet'  filename="component/create.go:92"
# INFO[0002] Creating Component: cert-manager ...          filename="ksonnet/ksonnet.go:207"
# INFO[0002] Args: [cert-manager cert-manager --acmeEmail fcady@algorithmia.io]  filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/cert-manager.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: cloud-endpoints ...       filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [cloud-endpoints cloud-endpoints]       filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/cloud-endpoints.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: gcp-credentials-admission-webhook ...  filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [gcp-credentials-admission-webhook gcp-credentials-admission-webhook]  filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/gcp-credentials-admission-webhook.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: gpu-driver ...            filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [gpu-driver gpu-driver]                 filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/gpu-driver.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: jupyter-web-app ...       filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [jupyter-web-app jupyter-web-app]       filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/jupyter-web-app.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: katib ...                 filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [katib katib]                           filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/katib.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: metacontroller ...        filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [metacontroller metacontroller]         filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/metacontroller.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: notebook-controller ...   filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [notebook-controller notebook-controller]  filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/notebook-controller.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: pipeline ...              filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [pipeline pipeline]                     filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/pipeline.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: pytorch-operator ...      filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [pytorch-operator pytorch-operator]     filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/pytorch-operator.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: spartakus ...             filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [spartakus spartakus --usageId 7377553633814356386 --reportUsage true]  filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/spartakus.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: tensorboard ...           filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [tensorboard tensorboard]               filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/tensorboard.jsonnet'  filename="component/create.go:92"
# INFO[0003] Creating Component: tf-job-operator ...       filename="ksonnet/ksonnet.go:207"
# INFO[0003] Args: [tf-job-operator tf-job-operator]       filename="ksonnet/ksonnet.go:208"
# INFO[0003] Writing component at '/Users/fieldcady/Desktop/kube/kfapp2/ks_app/components/tf-job-operator.jsonnet'  filename="component/create.go:92"
# INFO[0000] deploying kubeflow application                filename="cmd/apply.go:35"
# INFO[0000] reading from /Users/fieldcady/Desktop/kube/kfapp2/app.yaml  filename="coordinator/coordinator.go:341"
# INFO[0000] Reading config file: /Users/fieldcady/Desktop/kube/kfapp2/gcp_config/storage-kubeflow.yaml  filename="gcp/gcp.go:181"
# INFO[0000] Reading import file: /Users/fieldcady/Desktop/kube/kfapp2/gcp_config/storage.jinja  filename="gcp/gcp.go:217"
# INFO[0001] Creating deployment kfapp2-storage            filename="gcp/gcp.go:347"
# WARN[0002] Creating kfapp2-storage status: RUNNING (op = operation-1564590640021-58efca55140e2-02e0f764-c8ab51df)  filename="gcp/gcp.go:293"
# WARN[0003] Creating kfapp2-storage status: RUNNING (op = operation-1564590640021-58efca55140e2-02e0f764-c8ab51df)  filename="gcp/gcp.go:293"
# WARN[0004] Creating kfapp2-storage status: RUNNING (op = operation-1564590640021-58efca55140e2-02e0f764-c8ab51df)  filename="gcp/gcp.go:293"
# WARN[0006] Creating kfapp2-storage status: RUNNING (op = operation-1564590640021-58efca55140e2-02e0f764-c8ab51df)  filename="gcp/gcp.go:293"
# WARN[0007] Creating kfapp2-storage status: RUNNING (op = operation-1564590640021-58efca55140e2-02e0f764-c8ab51df)  filename="gcp/gcp.go:293"
# WARN[0010] Creating kfapp2-storage status: RUNNING (op = operation-1564590640021-58efca55140e2-02e0f764-c8ab51df)  filename="gcp/gcp.go:293"
# WARN[0013] Creating kfapp2-storage status: RUNNING (op = operation-1564590640021-58efca55140e2-02e0f764-c8ab51df)  filename="gcp/gcp.go:293"
# INFO[0021] Creating kfapp2-storage is finished: DONE     filename="gcp/gcp.go:290"
# INFO[0021] Reading config file: /Users/fieldcady/Desktop/kube/kfapp2/gcp_config/cluster-kubeflow.yaml  filename="gcp/gcp.go:181"
# INFO[0021] Reading import file: /Users/fieldcady/Desktop/kube/kfapp2/gcp_config/cluster.jinja  filename="gcp/gcp.go:217"
# INFO[0021] Creating deployment kfapp2                    filename="gcp/gcp.go:347"
# WARN[0022] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0022] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0023] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0025] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0027] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0031] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0033] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0040] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0052] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0063] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0083] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0114] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0164] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# WARN[0255] Creating kfapp2 status: RUNNING (op = operation-1564590660125-58efca6840197-86732489-07263187)  filename="gcp/gcp.go:293"
# INFO[0325] Creating kfapp2 is finished: DONE             filename="gcp/gcp.go:290"
# INFO[0327] Creating namespace: kubeflow                  filename="gcp/gcp.go:361"
# INFO[0327] Get namespace error: namespaces "kubeflow" not found  filename="gcp/gcp.go:367"
# INFO[0327] Binding admin role for fcady@algorithmia.io ...  filename="gcp/gcp.go:386"
# INFO[0327] default-admin not found, creating...          filename="gcp/gcp.go:420"
# INFO[0327] Secret for admin-gcp-sa not found, creating ...  filename="gcp/gcp.go:1320"
# INFO[0329] Secret for user-gcp-sa not found, creating ...  filename="gcp/gcp.go:1320"
# WARN[0329] Updating basic auth login is failed, trying to create one: secrets "kubeflow-login" not found  filename="gcp/gcp.go:1387"
# INFO[0329] Running get-credentials kfapp2 --zone=us-west2-c --project=kubeflow-245520 ...  filename="gcp/gcp.go:785"
# INFO[0330] KUBECONFIG name is gke_kubeflow-245520_us-west2-c_kfapp2  filename="gcp/gcp.go:454"
# INFO[0330] KUBECONFIG context kfapp2 is created and currently using  filename="gcp/gcp.go:551"
# INFO[0330] reading from /Users/fieldcady/Desktop/kube/kfapp2/app.yaml  filename="coordinator/coordinator.go:341"
# INFO[0330] namespace: kubeflow                           filename="ksonnet/ksonnet.go:109"
# INFO[0338] Applying services kubeflow.ambassador         filename="cluster/upsert.go:73"
# INFO[0339] Creating non-existent services kubeflow.ambassador  filename="cluster/upsert.go:92"
# INFO[0339] Applying services kubeflow.ambassador-admin   filename="cluster/upsert.go:73"
# INFO[0339] Creating non-existent services kubeflow.ambassador-admin  filename="cluster/upsert.go:92"
# INFO[0339] Applying clusterroles ambassador              filename="cluster/upsert.go:73"
# INFO[0340] Creating non-existent clusterroles ambassador  filename="cluster/upsert.go:92"
# INFO[0340] Applying serviceaccounts kubeflow.ambassador  filename="cluster/upsert.go:73"
# INFO[0340] Creating non-existent serviceaccounts kubeflow.ambassador  filename="cluster/upsert.go:92"
# INFO[0341] Applying clusterrolebindings ambassador       filename="cluster/upsert.go:73"
# INFO[0341] Creating non-existent clusterrolebindings ambassador  filename="cluster/upsert.go:92"
# INFO[0341] Applying deployments kubeflow.ambassador      filename="cluster/upsert.go:73"
# INFO[0341] Creating non-existent deployments kubeflow.ambassador  filename="cluster/upsert.go:92"
# INFO[0341] Component ambassador apply succeeded          filename="ksonnet/ksonnet.go:171"
# INFO[0347] Applying customresourcedefinitions workflows.argoproj.io  filename="cluster/upsert.go:73"
# INFO[0347] Creating non-existent customresourcedefinitions workflows.argoproj.io  filename="cluster/upsert.go:92"
# INFO[0347] Applying clusterrolebindings argo             filename="cluster/upsert.go:73"
# INFO[0348] Creating non-existent clusterrolebindings argo  filename="cluster/upsert.go:92"
# INFO[0348] Applying serviceaccounts kubeflow.argo-ui     filename="cluster/upsert.go:73"
# INFO[0349] Creating non-existent serviceaccounts kubeflow.argo-ui  filename="cluster/upsert.go:92"
# INFO[0349] Applying services kubeflow.argo-ui            filename="cluster/upsert.go:73"
# INFO[0349] Creating non-existent services kubeflow.argo-ui  filename="cluster/upsert.go:92"
# INFO[0349] Applying configmaps kubeflow.workflow-controller-configmap  filename="cluster/upsert.go:73"
# INFO[0350] Creating non-existent configmaps kubeflow.workflow-controller-configmap  filename="cluster/upsert.go:92"
# INFO[0350] Applying serviceaccounts kubeflow.argo        filename="cluster/upsert.go:73"
# INFO[0350] Creating non-existent serviceaccounts kubeflow.argo  filename="cluster/upsert.go:92"
# INFO[0350] Applying clusterroles argo                    filename="cluster/upsert.go:73"
# INFO[0350] Creating non-existent clusterroles argo       filename="cluster/upsert.go:92"
# INFO[0351] Applying clusterroles argo-ui                 filename="cluster/upsert.go:73"
# INFO[0351] Creating non-existent clusterroles argo-ui    filename="cluster/upsert.go:92"
# INFO[0351] Applying clusterrolebindings argo-ui          filename="cluster/upsert.go:73"
# INFO[0351] Creating non-existent clusterrolebindings argo-ui  filename="cluster/upsert.go:92"
# INFO[0352] Applying deployments kubeflow.workflow-controller  filename="cluster/upsert.go:73"
# INFO[0352] Creating non-existent deployments kubeflow.workflow-controller  filename="cluster/upsert.go:92"
# INFO[0352] Applying deployments kubeflow.argo-ui         filename="cluster/upsert.go:73"
# INFO[0353] Creating non-existent deployments kubeflow.argo-ui  filename="cluster/upsert.go:92"
# INFO[0353] Component argo apply succeeded                filename="ksonnet/ksonnet.go:171"
# INFO[0358] Applying services kubeflow.basic-auth         filename="cluster/upsert.go:73"
# INFO[0359] Creating non-existent services kubeflow.basic-auth  filename="cluster/upsert.go:92"
# INFO[0359] Applying services kubeflow.basic-auth-login   filename="cluster/upsert.go:73"
# INFO[0359] Creating non-existent services kubeflow.basic-auth-login  filename="cluster/upsert.go:92"
# INFO[0360] Applying deployments kubeflow.basic-auth      filename="cluster/upsert.go:73"
# INFO[0360] Creating non-existent deployments kubeflow.basic-auth  filename="cluster/upsert.go:92"
# INFO[0361] Applying deployments kubeflow.basic-auth-login  filename="cluster/upsert.go:73"
# INFO[0361] Creating non-existent deployments kubeflow.basic-auth-login  filename="cluster/upsert.go:92"
# INFO[0361] Component basic-auth apply succeeded          filename="ksonnet/ksonnet.go:171"
# INFO[0366] Applying serviceaccounts kubeflow.envoy       filename="cluster/upsert.go:73"
# INFO[0366] Creating non-existent serviceaccounts kubeflow.envoy  filename="cluster/upsert.go:92"
# INFO[0367] Applying clusterrolebindings envoy            filename="cluster/upsert.go:73"
# INFO[0367] Creating non-existent clusterrolebindings envoy  filename="cluster/upsert.go:92"
# INFO[0367] Applying clusterroles kubeflow.envoy          filename="cluster/upsert.go:73"
# INFO[0367] Creating non-existent clusterroles kubeflow.envoy  filename="cluster/upsert.go:92"
# INFO[0368] Applying services kubeflow.whoami-app         filename="cluster/upsert.go:73"
# INFO[0368] Creating non-existent services kubeflow.whoami-app  filename="cluster/upsert.go:92"
# ERRO[0370] (Will retry) Component basic-auth-ingress apply failed; Error: handle object: patching object from cluster: merging object with existing state: unable to recognize "/var/folders/h1/38y7h04s4rj6647157c_3rfh0000gn/T/ksonnet-mergepatch819770161": no matches for kind "Certificate" in version "certmanager.k8s.io/v1alpha1"  filename="ksonnet/ksonnet.go:174"
# INFO[0375] Applying clusterrolebindings centraldashboard  filename="cluster/upsert.go:73"
# INFO[0375] Creating non-existent clusterrolebindings centraldashboard  filename="cluster/upsert.go:92"
# INFO[0376] Applying services kubeflow.centraldashboard   filename="cluster/upsert.go:73"
# INFO[0376] Creating non-existent services kubeflow.centraldashboard  filename="cluster/upsert.go:92"
# INFO[0376] Applying serviceaccounts kubeflow.centraldashboard  filename="cluster/upsert.go:73"
# INFO[0376] Creating non-existent serviceaccounts kubeflow.centraldashboard  filename="cluster/upsert.go:92"
# INFO[0377] Applying roles kubeflow.centraldashboard      filename="cluster/upsert.go:73"
# INFO[0377] Creating non-existent roles kubeflow.centraldashboard  filename="cluster/upsert.go:92"
# INFO[0378] Applying rolebindings kubeflow.centraldashboard  filename="cluster/upsert.go:73"
# INFO[0378] Creating non-existent rolebindings kubeflow.centraldashboard  filename="cluster/upsert.go:92"
# INFO[0378] Applying clusterroles centraldashboard        filename="cluster/upsert.go:73"
# INFO[0378] Creating non-existent clusterroles centraldashboard  filename="cluster/upsert.go:92"
# INFO[0379] Applying deployments kubeflow.centraldashboard  filename="cluster/upsert.go:73"
# INFO[0379] Creating non-existent deployments kubeflow.centraldashboard  filename="cluster/upsert.go:92"
# INFO[0379] Component centraldashboard apply succeeded    filename="ksonnet/ksonnet.go:171"
# INFO[0384] Applying customresourcedefinitions certificates.certmanager.k8s.io  filename="cluster/upsert.go:73"
# INFO[0385] Creating non-existent customresourcedefinitions certificates.certmanager.k8s.io  filename="cluster/upsert.go:92"
# INFO[0385] Applying customresourcedefinitions clusterissuers.certmanager.k8s.io  filename="cluster/upsert.go:73"
# INFO[0385] Creating non-existent customresourcedefinitions clusterissuers.certmanager.k8s.io  filename="cluster/upsert.go:92"
# INFO[0385] Applying customresourcedefinitions issuers.certmanager.k8s.io  filename="cluster/upsert.go:73"
# INFO[0385] Creating non-existent customresourcedefinitions issuers.certmanager.k8s.io  filename="cluster/upsert.go:92"
# INFO[0386] Applying serviceaccounts kubeflow.cert-manager  filename="cluster/upsert.go:73"
# INFO[0386] Creating non-existent serviceaccounts kubeflow.cert-manager  filename="cluster/upsert.go:92"
# INFO[0387] Applying clusterroles cert-manager            filename="cluster/upsert.go:73"
# INFO[0387] Creating non-existent clusterroles cert-manager  filename="cluster/upsert.go:92"
# INFO[0387] Applying clusterrolebindings cert-manager     filename="cluster/upsert.go:73"
# INFO[0387] Creating non-existent clusterrolebindings cert-manager  filename="cluster/upsert.go:92"
# INFO[0388] Applying deployments kubeflow.cert-manager    filename="cluster/upsert.go:73"
# INFO[0388] Creating non-existent deployments kubeflow.cert-manager  filename="cluster/upsert.go:92"
# INFO[0390] Applying clusterissuers letsencrypt-prod      filename="cluster/upsert.go:73"
# INFO[0390] Creating non-existent clusterissuers letsencrypt-prod  filename="cluster/upsert.go:92"
# INFO[0390] Component cert-manager apply succeeded        filename="ksonnet/ksonnet.go:171"
# INFO[0396] Applying customresourcedefinitions cloudendpoints.ctl.isla.solutions  filename="cluster/upsert.go:73"
# INFO[0396] Creating non-existent customresourcedefinitions cloudendpoints.ctl.isla.solutions  filename="cluster/upsert.go:92"
# INFO[0397] Applying clusterroles cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0397] Creating non-existent clusterroles cloud-endpoints-controller  filename="cluster/upsert.go:92"
# INFO[0398] Applying clusterrolebindings cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0398] Creating non-existent clusterrolebindings cloud-endpoints-controller  filename="cluster/upsert.go:92"
# INFO[0398] Applying services kubeflow.cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0399] Creating non-existent services kubeflow.cloud-endpoints-controller  filename="cluster/upsert.go:92"
# INFO[0400] Applying serviceaccounts kubeflow.cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0400] Creating non-existent serviceaccounts kubeflow.cloud-endpoints-controller  filename="cluster/upsert.go:92"
# INFO[0400] Applying deployments kubeflow.cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0400] Creating non-existent deployments kubeflow.cloud-endpoints-controller  filename="cluster/upsert.go:92"
# ERRO[0402] (Will retry) Component cloud-endpoints apply failed; Error: handle object: patching object from cluster: merging object with existing state: unable to recognize "/var/folders/h1/38y7h04s4rj6647157c_3rfh0000gn/T/ksonnet-mergepatch075518304": no matches for kind "CompositeController" in version "metacontroller.k8s.io/v1alpha1"  filename="ksonnet/ksonnet.go:174"
# INFO[0407] Applying clusterroles webhook-bootstrap       filename="cluster/upsert.go:73"
# INFO[0408] Creating non-existent clusterroles webhook-bootstrap  filename="cluster/upsert.go:92"
# INFO[0408] Applying services kubeflow.gcp-cred-webhook   filename="cluster/upsert.go:73"
# INFO[0408] Creating non-existent services kubeflow.gcp-cred-webhook  filename="cluster/upsert.go:92"
# INFO[0409] Applying configmaps kubeflow.webhook-bootstrap-config  filename="cluster/upsert.go:73"
# INFO[0409] Creating non-existent configmaps kubeflow.webhook-bootstrap-config  filename="cluster/upsert.go:92"
# INFO[0409] Applying mutatingwebhookconfigurations gcp-cred-webhook  filename="cluster/upsert.go:73"
# INFO[0410] Creating non-existent mutatingwebhookconfigurations gcp-cred-webhook  filename="cluster/upsert.go:92"
# INFO[0410] Applying serviceaccounts kubeflow.webhook-bootstrap  filename="cluster/upsert.go:73"
# INFO[0410] Creating non-existent serviceaccounts kubeflow.webhook-bootstrap  filename="cluster/upsert.go:92"
# INFO[0411] Applying clusterrolebindings webhook-bootstrap  filename="cluster/upsert.go:73"
# INFO[0411] Creating non-existent clusterrolebindings webhook-bootstrap  filename="cluster/upsert.go:92"
# INFO[0411] Applying statefulsets kubeflow.webhook-bootstrap  filename="cluster/upsert.go:73"
# INFO[0411] Creating non-existent statefulsets kubeflow.webhook-bootstrap  filename="cluster/upsert.go:92"
# INFO[0412] Applying deployments kubeflow.gcp-cred-webhook  filename="cluster/upsert.go:73"
# INFO[0412] Creating non-existent deployments kubeflow.gcp-cred-webhook  filename="cluster/upsert.go:92"
# INFO[0412] Component gcp-credentials-admission-webhook apply succeeded  filename="ksonnet/ksonnet.go:171"
# INFO[0418] Applying daemonsets kube-system.nvidia-driver-installer  filename="cluster/upsert.go:73"
# INFO[0418] Creating non-existent daemonsets kube-system.nvidia-driver-installer  filename="cluster/upsert.go:92"
# INFO[0418] Component gpu-driver apply succeeded          filename="ksonnet/ksonnet.go:171"
# INFO[0423] Applying services kubeflow.jupyter-web-app    filename="cluster/upsert.go:73"
# INFO[0424] Creating non-existent services kubeflow.jupyter-web-app  filename="cluster/upsert.go:92"
# INFO[0424] Applying deployments kubeflow.jupyter-web-app  filename="cluster/upsert.go:73"
# INFO[0424] Creating non-existent deployments kubeflow.jupyter-web-app  filename="cluster/upsert.go:92"
# INFO[0425] Applying configmaps kubeflow.jupyter-web-app-config  filename="cluster/upsert.go:73"
# INFO[0425] Creating non-existent configmaps kubeflow.jupyter-web-app-config  filename="cluster/upsert.go:92"
# INFO[0425] Applying serviceaccounts kubeflow.jupyter-web-app  filename="cluster/upsert.go:73"
# INFO[0425] Creating non-existent serviceaccounts kubeflow.jupyter-web-app  filename="cluster/upsert.go:92"
# INFO[0426] Applying clusterrolebindings jupyter-web-app-binding  filename="cluster/upsert.go:73"
# INFO[0426] Creating non-existent clusterrolebindings jupyter-web-app-binding  filename="cluster/upsert.go:92"
# INFO[0427] Applying clusterroles jupyter-web-app-cluster-role  filename="cluster/upsert.go:73"
# INFO[0427] Creating non-existent clusterroles jupyter-web-app-cluster-role  filename="cluster/upsert.go:92"
# INFO[0427] Applying serviceaccounts kubeflow.jupyter-notebook  filename="cluster/upsert.go:73"
# INFO[0427] Creating non-existent serviceaccounts kubeflow.jupyter-notebook  filename="cluster/upsert.go:92"
# INFO[0427] Applying roles kubeflow.jupyter-notebook-role  filename="cluster/upsert.go:73"
# INFO[0428] Creating non-existent roles kubeflow.jupyter-notebook-role  filename="cluster/upsert.go:92"
# INFO[0428] Applying rolebindings kubeflow.jupyter-notebook-role-binding  filename="cluster/upsert.go:73"
# INFO[0428] Creating non-existent rolebindings kubeflow.jupyter-notebook-role-binding  filename="cluster/upsert.go:92"
# INFO[0428] Component jupyter-web-app apply succeeded     filename="ksonnet/ksonnet.go:171"
# INFO[0434] Applying clusterroles metrics-collector       filename="cluster/upsert.go:73"
# INFO[0434] Creating non-existent clusterroles metrics-collector  filename="cluster/upsert.go:92"
# INFO[0435] Applying services kubeflow.studyjob-controller  filename="cluster/upsert.go:73"
# INFO[0435] Creating non-existent services kubeflow.studyjob-controller  filename="cluster/upsert.go:92"
# INFO[0435] Applying services kubeflow.vizier-db          filename="cluster/upsert.go:73"
# INFO[0436] Creating non-existent services kubeflow.vizier-db  filename="cluster/upsert.go:92"
# INFO[0436] Applying persistentvolumeclaims kubeflow.katib-mysql  filename="cluster/upsert.go:73"
# INFO[0436] Creating non-existent persistentvolumeclaims kubeflow.katib-mysql  filename="cluster/upsert.go:92"
# INFO[0436] Applying clusterrolebindings studyjob-controller  filename="cluster/upsert.go:73"
# INFO[0436] Creating non-existent clusterrolebindings studyjob-controller  filename="cluster/upsert.go:92"
# INFO[0437] Applying secrets kubeflow.vizier-db-secrets   filename="cluster/upsert.go:73"
# INFO[0437] Creating non-existent secrets kubeflow.vizier-db-secrets  filename="cluster/upsert.go:92"
# INFO[0437] Applying clusterroles vizier-core             filename="cluster/upsert.go:73"
# INFO[0438] Creating non-existent clusterroles vizier-core  filename="cluster/upsert.go:92"
# INFO[0438] Applying clusterrolebindings vizier-core      filename="cluster/upsert.go:73"
# INFO[0438] Creating non-existent clusterrolebindings vizier-core  filename="cluster/upsert.go:92"
# INFO[0439] Applying serviceaccounts kubeflow.vizier-core  filename="cluster/upsert.go:73"
# INFO[0439] Creating non-existent serviceaccounts kubeflow.vizier-core  filename="cluster/upsert.go:92"
# INFO[0439] Applying services kubeflow.vizier-core-rest   filename="cluster/upsert.go:73"
# INFO[0439] Creating non-existent services kubeflow.vizier-core-rest  filename="cluster/upsert.go:92"
# INFO[0439] Applying serviceaccounts kubeflow.studyjob-controller  filename="cluster/upsert.go:73"
# INFO[0439] Creating non-existent serviceaccounts kubeflow.studyjob-controller  filename="cluster/upsert.go:92"
# INFO[0440] Applying services kubeflow.katib-ui           filename="cluster/upsert.go:73"
# INFO[0440] Creating non-existent services kubeflow.katib-ui  filename="cluster/upsert.go:92"
# INFO[0440] Applying clusterroles studyjob-controller     filename="cluster/upsert.go:73"
# INFO[0440] Creating non-existent clusterroles studyjob-controller  filename="cluster/upsert.go:92"
# INFO[0441] Applying clusterroles katib-ui                filename="cluster/upsert.go:73"
# INFO[0441] Creating non-existent clusterroles katib-ui   filename="cluster/upsert.go:92"
# INFO[0441] Applying clusterrolebindings katib-ui         filename="cluster/upsert.go:73"
# INFO[0441] Creating non-existent clusterrolebindings katib-ui  filename="cluster/upsert.go:92"
# INFO[0442] Applying serviceaccounts kubeflow.katib-ui    filename="cluster/upsert.go:73"
# INFO[0442] Creating non-existent serviceaccounts kubeflow.katib-ui  filename="cluster/upsert.go:92"
# INFO[0442] Applying services kubeflow.vizier-suggestion-random  filename="cluster/upsert.go:73"
# INFO[0442] Creating non-existent services kubeflow.vizier-suggestion-random  filename="cluster/upsert.go:92"
# INFO[0443] Applying services kubeflow.vizier-core        filename="cluster/upsert.go:73"
# INFO[0443] Creating non-existent services kubeflow.vizier-core  filename="cluster/upsert.go:92"
# INFO[0443] Applying services kubeflow.vizier-suggestion-grid  filename="cluster/upsert.go:73"
# INFO[0443] Creating non-existent services kubeflow.vizier-suggestion-grid  filename="cluster/upsert.go:92"
# INFO[0444] Applying configmaps kubeflow.metricscollector-template  filename="cluster/upsert.go:73"
# INFO[0444] Creating non-existent configmaps kubeflow.metricscollector-template  filename="cluster/upsert.go:92"
# INFO[0444] Applying services kubeflow.vizier-suggestion-hyperband  filename="cluster/upsert.go:73"
# INFO[0444] Creating non-existent services kubeflow.vizier-suggestion-hyperband  filename="cluster/upsert.go:92"
# INFO[0444] Applying clusterrolebindings metrics-collector  filename="cluster/upsert.go:73"
# INFO[0445] Creating non-existent clusterrolebindings metrics-collector  filename="cluster/upsert.go:92"
# INFO[0445] Applying services kubeflow.vizier-suggestion-bayesianoptimization  filename="cluster/upsert.go:73"
# INFO[0445] Creating non-existent services kubeflow.vizier-suggestion-bayesianoptimization  filename="cluster/upsert.go:92"
# INFO[0445] Applying serviceaccounts kubeflow.metrics-collector  filename="cluster/upsert.go:73"
# INFO[0445] Creating non-existent serviceaccounts kubeflow.metrics-collector  filename="cluster/upsert.go:92"
# INFO[0446] Applying customresourcedefinitions studyjobs.kubeflow.org  filename="cluster/upsert.go:73"
# INFO[0446] Creating non-existent customresourcedefinitions studyjobs.kubeflow.org  filename="cluster/upsert.go:92"
# INFO[0447] Applying configmaps kubeflow.worker-template  filename="cluster/upsert.go:73"
# INFO[0447] Creating non-existent configmaps kubeflow.worker-template  filename="cluster/upsert.go:92"
# INFO[0447] Applying deployments kubeflow.vizier-suggestion-bayesianoptimization  filename="cluster/upsert.go:73"
# INFO[0447] Creating non-existent deployments kubeflow.vizier-suggestion-bayesianoptimization  filename="cluster/upsert.go:92"
# INFO[0448] Applying deployments kubeflow.vizier-suggestion-hyperband  filename="cluster/upsert.go:73"
# INFO[0448] Creating non-existent deployments kubeflow.vizier-suggestion-hyperband  filename="cluster/upsert.go:92"
# INFO[0448] Applying deployments kubeflow.vizier-suggestion-grid  filename="cluster/upsert.go:73"
# INFO[0448] Creating non-existent deployments kubeflow.vizier-suggestion-grid  filename="cluster/upsert.go:92"
# INFO[0449] Applying deployments kubeflow.katib-ui        filename="cluster/upsert.go:73"
# INFO[0449] Creating non-existent deployments kubeflow.katib-ui  filename="cluster/upsert.go:92"
# INFO[0449] Applying deployments kubeflow.vizier-core-rest  filename="cluster/upsert.go:73"
# INFO[0449] Creating non-existent deployments kubeflow.vizier-core-rest  filename="cluster/upsert.go:92"
# INFO[0450] Applying deployments kubeflow.vizier-db       filename="cluster/upsert.go:73"
# INFO[0450] Creating non-existent deployments kubeflow.vizier-db  filename="cluster/upsert.go:92"
# INFO[0450] Applying deployments kubeflow.studyjob-controller  filename="cluster/upsert.go:73"
# INFO[0450] Creating non-existent deployments kubeflow.studyjob-controller  filename="cluster/upsert.go:92"
# INFO[0451] Applying deployments kubeflow.vizier-core     filename="cluster/upsert.go:73"
# INFO[0451] Creating non-existent deployments kubeflow.vizier-core  filename="cluster/upsert.go:92"
# INFO[0451] Applying deployments kubeflow.vizier-suggestion-random  filename="cluster/upsert.go:73"
# INFO[0451] Creating non-existent deployments kubeflow.vizier-suggestion-random  filename="cluster/upsert.go:92"
# INFO[0451] Component katib apply succeeded               filename="ksonnet/ksonnet.go:171"
# INFO[0457] Applying customresourcedefinitions compositecontrollers.metacontroller.k8s.io  filename="cluster/upsert.go:73"
# INFO[0457] Creating non-existent customresourcedefinitions compositecontrollers.metacontroller.k8s.io  filename="cluster/upsert.go:92"
# INFO[0457] Applying customresourcedefinitions controllerrevisions.metacontroller.k8s.io  filename="cluster/upsert.go:73"
# INFO[0457] Creating non-existent customresourcedefinitions controllerrevisions.metacontroller.k8s.io  filename="cluster/upsert.go:92"
# INFO[0458] Applying customresourcedefinitions decoratorcontrollers.metacontroller.k8s.io  filename="cluster/upsert.go:73"
# INFO[0458] Creating non-existent customresourcedefinitions decoratorcontrollers.metacontroller.k8s.io  filename="cluster/upsert.go:92"
# INFO[0458] Applying serviceaccounts kubeflow.meta-controller-service  filename="cluster/upsert.go:73"
# INFO[0459] Creating non-existent serviceaccounts kubeflow.meta-controller-service  filename="cluster/upsert.go:92"
# INFO[0459] Applying clusterrolebindings meta-controller-cluster-role-binding  filename="cluster/upsert.go:73"
# INFO[0460] Creating non-existent clusterrolebindings meta-controller-cluster-role-binding  filename="cluster/upsert.go:92"
# INFO[0460] Applying statefulsets kubeflow.metacontroller  filename="cluster/upsert.go:73"
# INFO[0461] Creating non-existent statefulsets kubeflow.metacontroller  filename="cluster/upsert.go:92"
# INFO[0461] Component metacontroller apply succeeded      filename="ksonnet/ksonnet.go:171"
# INFO[0466] Applying customresourcedefinitions notebooks.kubeflow.org  filename="cluster/upsert.go:73"
# INFO[0466] Creating non-existent customresourcedefinitions notebooks.kubeflow.org  filename="cluster/upsert.go:92"
# INFO[0467] Applying services kubeflow.notebooks-controller  filename="cluster/upsert.go:73"
# INFO[0467] Creating non-existent services kubeflow.notebooks-controller  filename="cluster/upsert.go:92"
# INFO[0468] Applying serviceaccounts kubeflow.notebook-controller  filename="cluster/upsert.go:73"
# INFO[0468] Creating non-existent serviceaccounts kubeflow.notebook-controller  filename="cluster/upsert.go:92"
# INFO[0468] Applying deployments kubeflow.notebooks-controller  filename="cluster/upsert.go:73"
# INFO[0468] Creating non-existent deployments kubeflow.notebooks-controller  filename="cluster/upsert.go:92"
# INFO[0469] Applying clusterroles notebooks-controller    filename="cluster/upsert.go:73"
# INFO[0469] Creating non-existent clusterroles notebooks-controller  filename="cluster/upsert.go:92"
# INFO[0470] Applying clusterrolebindings notebooks-controller  filename="cluster/upsert.go:73"
# INFO[0470] Creating non-existent clusterrolebindings notebooks-controller  filename="cluster/upsert.go:92"
# INFO[0470] Component notebook-controller apply succeeded  filename="ksonnet/ksonnet.go:171"
# INFO[0475] Applying services kubeflow.minio-service      filename="cluster/upsert.go:73"
# INFO[0475] Creating non-existent services kubeflow.minio-service  filename="cluster/upsert.go:92"
# INFO[0476] Applying deployments kubeflow.minio           filename="cluster/upsert.go:73"
# INFO[0476] Creating non-existent deployments kubeflow.minio  filename="cluster/upsert.go:92"
# INFO[0477] Applying secrets kubeflow.mlpipeline-minio-artifact  filename="cluster/upsert.go:73"
# INFO[0477] Creating non-existent secrets kubeflow.mlpipeline-minio-artifact  filename="cluster/upsert.go:92"
# INFO[0477] Applying services kubeflow.mysql              filename="cluster/upsert.go:73"
# INFO[0477] Creating non-existent services kubeflow.mysql  filename="cluster/upsert.go:92"
# INFO[0478] Applying deployments kubeflow.mysql           filename="cluster/upsert.go:73"
# INFO[0478] Creating non-existent deployments kubeflow.mysql  filename="cluster/upsert.go:92"
# INFO[0479] Applying serviceaccounts kubeflow.ml-pipeline  filename="cluster/upsert.go:73"
# INFO[0479] Creating non-existent serviceaccounts kubeflow.ml-pipeline  filename="cluster/upsert.go:92"
# INFO[0479] Applying rolebindings kubeflow.ml-pipeline    filename="cluster/upsert.go:73"
# INFO[0479] Creating non-existent rolebindings kubeflow.ml-pipeline  filename="cluster/upsert.go:92"
# INFO[0480] Applying roles kubeflow.ml-pipeline           filename="cluster/upsert.go:73"
# INFO[0480] Creating non-existent roles kubeflow.ml-pipeline  filename="cluster/upsert.go:92"
# INFO[0480] Applying services kubeflow.ml-pipeline        filename="cluster/upsert.go:73"
# INFO[0480] Creating non-existent services kubeflow.ml-pipeline  filename="cluster/upsert.go:92"
# INFO[0481] Applying deployments kubeflow.ml-pipeline     filename="cluster/upsert.go:73"
# INFO[0481] Creating non-existent deployments kubeflow.ml-pipeline  filename="cluster/upsert.go:92"
# INFO[0481] Applying serviceaccounts kubeflow.pipeline-runner  filename="cluster/upsert.go:73"
# INFO[0481] Creating non-existent serviceaccounts kubeflow.pipeline-runner  filename="cluster/upsert.go:92"
# INFO[0482] Applying clusterroles pipeline-runner         filename="cluster/upsert.go:73"
# INFO[0482] Creating non-existent clusterroles pipeline-runner  filename="cluster/upsert.go:92"
# INFO[0482] Applying clusterrolebindings pipeline-runner  filename="cluster/upsert.go:73"
# INFO[0482] Creating non-existent clusterrolebindings pipeline-runner  filename="cluster/upsert.go:92"
# INFO[0483] Applying serviceaccounts kubeflow.ml-pipeline-scheduledworkflow  filename="cluster/upsert.go:73"
# INFO[0483] Creating non-existent serviceaccounts kubeflow.ml-pipeline-scheduledworkflow  filename="cluster/upsert.go:92"
# INFO[0483] Applying clusterrolebindings ml-pipeline-scheduledworkflow  filename="cluster/upsert.go:73"
# INFO[0483] Creating non-existent clusterrolebindings ml-pipeline-scheduledworkflow  filename="cluster/upsert.go:92"
# INFO[0483] Applying roles kubeflow.ml-pipeline-scheduledworkflow  filename="cluster/upsert.go:73"
# INFO[0483] Creating non-existent roles kubeflow.ml-pipeline-scheduledworkflow  filename="cluster/upsert.go:92"
# INFO[0484] Applying deployments kubeflow.ml-pipeline-scheduledworkflow  filename="cluster/upsert.go:73"
# INFO[0484] Creating non-existent deployments kubeflow.ml-pipeline-scheduledworkflow  filename="cluster/upsert.go:92"
# INFO[0484] Applying customresourcedefinitions scheduledworkflows.kubeflow.org  filename="cluster/upsert.go:73"
# INFO[0485] Creating non-existent customresourcedefinitions scheduledworkflows.kubeflow.org  filename="cluster/upsert.go:92"
# INFO[0485] Applying serviceaccounts kubeflow.ml-pipeline-persistenceagent  filename="cluster/upsert.go:73"
# INFO[0485] Creating non-existent serviceaccounts kubeflow.ml-pipeline-persistenceagent  filename="cluster/upsert.go:92"
# INFO[0486] Applying clusterrolebindings ml-pipeline-persistenceagent  filename="cluster/upsert.go:73"
# INFO[0486] Creating non-existent clusterrolebindings ml-pipeline-persistenceagent  filename="cluster/upsert.go:92"
# INFO[0486] Applying clusterroles ml-pipeline-persistenceagent  filename="cluster/upsert.go:73"
# INFO[0486] Creating non-existent clusterroles ml-pipeline-persistenceagent  filename="cluster/upsert.go:92"
# INFO[0486] Applying deployments kubeflow.ml-pipeline-persistenceagent  filename="cluster/upsert.go:73"
# INFO[0486] Creating non-existent deployments kubeflow.ml-pipeline-persistenceagent  filename="cluster/upsert.go:92"
# INFO[0487] Applying serviceaccounts kubeflow.ml-pipeline-viewer-crd-service-account  filename="cluster/upsert.go:73"
# INFO[0487] Creating non-existent serviceaccounts kubeflow.ml-pipeline-viewer-crd-service-account  filename="cluster/upsert.go:92"
# INFO[0487] Applying clusterrolebindings ml-pipeline-viewer-crd-role-binding  filename="cluster/upsert.go:73"
# INFO[0487] Creating non-existent clusterrolebindings ml-pipeline-viewer-crd-role-binding  filename="cluster/upsert.go:92"
# INFO[0488] Applying clusterroles ml-pipeline-viewer-controller-role  filename="cluster/upsert.go:73"
# INFO[0488] Creating non-existent clusterroles ml-pipeline-viewer-controller-role  filename="cluster/upsert.go:92"
# INFO[0488] Applying deployments kubeflow.ml-pipeline-viewer-controller-deployment  filename="cluster/upsert.go:73"
# INFO[0488] Creating non-existent deployments kubeflow.ml-pipeline-viewer-controller-deployment  filename="cluster/upsert.go:92"
# INFO[0489] Applying customresourcedefinitions viewers.kubeflow.org  filename="cluster/upsert.go:73"
# INFO[0489] Creating non-existent customresourcedefinitions viewers.kubeflow.org  filename="cluster/upsert.go:92"
# INFO[0489] Applying serviceaccounts kubeflow.ml-pipeline-ui  filename="cluster/upsert.go:73"
# INFO[0490] Creating non-existent serviceaccounts kubeflow.ml-pipeline-ui  filename="cluster/upsert.go:92"
# INFO[0490] Applying services kubeflow.ml-pipeline-ui     filename="cluster/upsert.go:73"
# INFO[0490] Creating non-existent services kubeflow.ml-pipeline-ui  filename="cluster/upsert.go:92"
# INFO[0491] Applying services kubeflow.ml-pipeline-tensorboard-ui  filename="cluster/upsert.go:73"
# INFO[0491] Creating non-existent services kubeflow.ml-pipeline-tensorboard-ui  filename="cluster/upsert.go:92"
# INFO[0492] Applying rolebindings kubeflow.ml-pipeline-ui  filename="cluster/upsert.go:73"
# INFO[0492] Creating non-existent rolebindings kubeflow.ml-pipeline-ui  filename="cluster/upsert.go:92"
# INFO[0492] Applying roles kubeflow.ml-pipeline-ui        filename="cluster/upsert.go:73"
# INFO[0493] Creating non-existent roles kubeflow.ml-pipeline-ui  filename="cluster/upsert.go:92"
# INFO[0493] Applying deployments kubeflow.ml-pipeline-ui  filename="cluster/upsert.go:73"
# INFO[0493] Creating non-existent deployments kubeflow.ml-pipeline-ui  filename="cluster/upsert.go:92"
# INFO[0493] Applying persistentvolumeclaims kubeflow.mysql-pv-claim  filename="cluster/upsert.go:73"
# INFO[0493] Creating non-existent persistentvolumeclaims kubeflow.mysql-pv-claim  filename="cluster/upsert.go:92"
# INFO[0494] Applying persistentvolumeclaims kubeflow.minio-pvc  filename="cluster/upsert.go:73"
# INFO[0494] Creating non-existent persistentvolumeclaims kubeflow.minio-pvc  filename="cluster/upsert.go:92"
# INFO[0494] Applying persistentvolumes kubeflow.mysql-pv  filename="cluster/upsert.go:73"
# INFO[0494] Creating non-existent persistentvolumes kubeflow.mysql-pv  filename="cluster/upsert.go:92"
# INFO[0495] Applying persistentvolumes kubeflow.minio-pv  filename="cluster/upsert.go:73"
# INFO[0496] Creating non-existent persistentvolumes kubeflow.minio-pv  filename="cluster/upsert.go:92"
# INFO[0496] Component pipeline apply succeeded            filename="ksonnet/ksonnet.go:171"
# INFO[0501] Applying configmaps kubeflow.pytorch-operator-config  filename="cluster/upsert.go:73"
# INFO[0502] Creating non-existent configmaps kubeflow.pytorch-operator-config  filename="cluster/upsert.go:92"
# INFO[0502] Applying serviceaccounts kubeflow.pytorch-operator  filename="cluster/upsert.go:73"
# INFO[0502] Creating non-existent serviceaccounts kubeflow.pytorch-operator  filename="cluster/upsert.go:92"
# INFO[0503] Applying clusterroles pytorch-operator        filename="cluster/upsert.go:73"
# INFO[0503] Creating non-existent clusterroles pytorch-operator  filename="cluster/upsert.go:92"
# INFO[0503] Applying clusterrolebindings pytorch-operator  filename="cluster/upsert.go:73"
# INFO[0503] Creating non-existent clusterrolebindings pytorch-operator  filename="cluster/upsert.go:92"
# INFO[0504] Applying customresourcedefinitions pytorchjobs.kubeflow.org  filename="cluster/upsert.go:73"
# INFO[0504] Creating non-existent customresourcedefinitions pytorchjobs.kubeflow.org  filename="cluster/upsert.go:92"
# INFO[0505] Applying deployments kubeflow.pytorch-operator  filename="cluster/upsert.go:73"
# INFO[0505] Creating non-existent deployments kubeflow.pytorch-operator  filename="cluster/upsert.go:92"
# INFO[0505] Component pytorch-operator apply succeeded    filename="ksonnet/ksonnet.go:171"
# INFO[0511] Applying clusterroles spartakus               filename="cluster/upsert.go:73"
# INFO[0511] Creating non-existent clusterroles spartakus  filename="cluster/upsert.go:92"
# INFO[0512] Applying clusterrolebindings spartakus        filename="cluster/upsert.go:73"
# INFO[0512] Creating non-existent clusterrolebindings spartakus  filename="cluster/upsert.go:92"
# INFO[0513] Applying serviceaccounts kubeflow.spartakus   filename="cluster/upsert.go:73"
# INFO[0513] Creating non-existent serviceaccounts kubeflow.spartakus  filename="cluster/upsert.go:92"
# INFO[0513] Applying deployments kubeflow.spartakus-volunteer  filename="cluster/upsert.go:73"
# INFO[0514] Creating non-existent deployments kubeflow.spartakus-volunteer  filename="cluster/upsert.go:92"
# INFO[0514] Component spartakus apply succeeded           filename="ksonnet/ksonnet.go:171"
# INFO[0519] Applying services kubeflow.tensorboard        filename="cluster/upsert.go:73"
# INFO[0519] Creating non-existent services kubeflow.tensorboard  filename="cluster/upsert.go:92"
# INFO[0520] Applying deployments kubeflow.tensorboard     filename="cluster/upsert.go:73"
# INFO[0520] Creating non-existent deployments kubeflow.tensorboard  filename="cluster/upsert.go:92"
# INFO[0520] Component tensorboard apply succeeded         filename="ksonnet/ksonnet.go:171"
# INFO[0525] Applying customresourcedefinitions tfjobs.kubeflow.org  filename="cluster/upsert.go:73"
# INFO[0526] Creating non-existent customresourcedefinitions tfjobs.kubeflow.org  filename="cluster/upsert.go:92"
# INFO[0526] Applying serviceaccounts kubeflow.tf-job-dashboard  filename="cluster/upsert.go:73"
# INFO[0527] Creating non-existent serviceaccounts kubeflow.tf-job-dashboard  filename="cluster/upsert.go:92"
# INFO[0527] Applying configmaps kubeflow.tf-job-operator-config  filename="cluster/upsert.go:73"
# INFO[0527] Creating non-existent configmaps kubeflow.tf-job-operator-config  filename="cluster/upsert.go:92"
# INFO[0527] Applying serviceaccounts kubeflow.tf-job-operator  filename="cluster/upsert.go:73"
# INFO[0527] Creating non-existent serviceaccounts kubeflow.tf-job-operator  filename="cluster/upsert.go:92"
# INFO[0528] Applying clusterroles tf-job-operator         filename="cluster/upsert.go:73"
# INFO[0528] Creating non-existent clusterroles tf-job-operator  filename="cluster/upsert.go:92"
# INFO[0529] Applying clusterrolebindings tf-job-operator  filename="cluster/upsert.go:73"
# INFO[0529] Creating non-existent clusterrolebindings tf-job-operator  filename="cluster/upsert.go:92"
# INFO[0529] Applying services kubeflow.tf-job-dashboard   filename="cluster/upsert.go:73"
# INFO[0529] Creating non-existent services kubeflow.tf-job-dashboard  filename="cluster/upsert.go:92"
# INFO[0530] Applying clusterroles tf-job-dashboard        filename="cluster/upsert.go:73"
# INFO[0530] Creating non-existent clusterroles tf-job-dashboard  filename="cluster/upsert.go:92"
# INFO[0530] Applying clusterrolebindings tf-job-dashboard  filename="cluster/upsert.go:73"
# INFO[0530] Creating non-existent clusterrolebindings tf-job-dashboard  filename="cluster/upsert.go:92"
# INFO[0531] Applying deployments kubeflow.tf-job-operator  filename="cluster/upsert.go:73"
# INFO[0531] Creating non-existent deployments kubeflow.tf-job-operator  filename="cluster/upsert.go:92"
# INFO[0532] Applying deployments kubeflow.tf-job-dashboard  filename="cluster/upsert.go:73"
# INFO[0532] Creating non-existent deployments kubeflow.tf-job-dashboard  filename="cluster/upsert.go:92"
# INFO[0532] Component tf-job-operator apply succeeded     filename="ksonnet/ksonnet.go:171"
# INFO[0543] Applying serviceaccounts kubeflow.envoy       filename="cluster/upsert.go:73"
# INFO[0544] Applying clusterrolebindings envoy            filename="cluster/upsert.go:73"
# INFO[0546] Applying clusterroles envoy                   filename="cluster/upsert.go:73"
# INFO[0547] Applying services kubeflow.whoami-app         filename="cluster/upsert.go:73"
# INFO[0547] Applying certificates kubeflow.envoy-ingress-tls  filename="cluster/upsert.go:73"
# INFO[0547] Creating non-existent certificates kubeflow.envoy-ingress-tls  filename="cluster/upsert.go:92"
# INFO[0548] Applying cloudendpoints kubeflow.kfapp2       filename="cluster/upsert.go:73"
# INFO[0548] Creating non-existent cloudendpoints kubeflow.kfapp2  filename="cluster/upsert.go:92"
# INFO[0548] Applying configmaps kubeflow.envoy-config     filename="cluster/upsert.go:73"
# INFO[0549] Creating non-existent configmaps kubeflow.envoy-config  filename="cluster/upsert.go:92"
# INFO[0549] Applying configmaps kubeflow.ingress-bootstrap-config  filename="cluster/upsert.go:73"
# INFO[0549] Creating non-existent configmaps kubeflow.ingress-bootstrap-config  filename="cluster/upsert.go:92"
# INFO[0549] Applying ingresses kubeflow.envoy-ingress     filename="cluster/upsert.go:73"
# INFO[0550] Creating non-existent ingresses kubeflow.envoy-ingress  filename="cluster/upsert.go:92"
# INFO[0550] Applying jobs kubeflow.ingress-bootstrap      filename="cluster/upsert.go:73"
# INFO[0551] Creating non-existent jobs kubeflow.ingress-bootstrap  filename="cluster/upsert.go:92"
# INFO[0551] Applying deployments kubeflow.whoami-app      filename="cluster/upsert.go:73"
# INFO[0551] Creating non-existent deployments kubeflow.whoami-app  filename="cluster/upsert.go:92"
# INFO[0551] Applying statefulsets kubeflow.backend-updater  filename="cluster/upsert.go:73"
# INFO[0552] Creating non-existent statefulsets kubeflow.backend-updater  filename="cluster/upsert.go:92"
# INFO[0552] Component basic-auth-ingress apply succeeded  filename="ksonnet/ksonnet.go:171"
# INFO[0557] Applying customresourcedefinitions cloudendpoints.ctl.isla.solutions  filename="cluster/upsert.go:73"
# INFO[0558] Applying clusterroles cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0560] Applying clusterrolebindings cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0561] Applying services kubeflow.cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0562] Applying serviceaccounts kubeflow.cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0563] Applying deployments kubeflow.cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0565] Applying compositecontrollers cloud-endpoints-controller  filename="cluster/upsert.go:73"
# INFO[0566] Creating non-existent compositecontrollers cloud-endpoints-controller  filename="cluster/upsert.go:92"
# INFO[0566] Component cloud-endpoints apply succeeded     filename="ksonnet/ksonnet.go:171"
# INFO[0566] All components apply succeeded                filename="ksonnet/ksonnet.go:192"

# %% [markdown]
# After the cluster starts you can see it at ```https://${KFAPP}.endpoints.${PROJECT}.cloud.goog/```
#
# Next connect to Kubeflow cluster+deployment:

# %%
#%%capture
# !gcloud container clusters get-credentials $KFAPP --zone $ZONE --project $PROJECT
# Out:
# Fetching cluster endpoint and auth data.
# kubeconfig entry generated for kfapp2.

# %% [markdown]
# # STEP 4: Make Storage Bucket
# Now we will set up a cloud storage location where our trained model will be stored:

# %%
BUCKET_NAME=PROJECT + '-' + KFAPP + '-bucket'

# %%
# !echo $ZONE gs://$BUCKET_NAME
# !gsutil mb -c regional -l $REGION gs://$BUCKET_NAME
# Out:
# us-west2-c gs://kubeflow-245520-kfapp2-bucket
# Creating gs://kubeflow-245520-kfapp2-bucket/...

# %% [markdown]
# You should see the bucket listed at ```https://console.cloud.google.com/storage/browser?project=<PROJECT>```.

# %% [markdown]
# # STEP 5: Get code, build training Docker image, and Push it to the Registry
# The next step for getting Kubeflow running is to get the Docker training image built and stored in GCE where Kubeflow can find it.
#
# This is where you will start changing things for your own projects, but for this walk-through we will use the MNIST example.

# %%
import datetime
import time
VERSION_TAG=str(round(time.time()))
TRAIN_IMG_PATH=f"gcr.io/{PROJECT}/{KFAPP}-train:{VERSION_TAG}"
WORKING_DIR="/Users/fieldcady/Desktop/examples/mnist"
print(TRAIN_IMG_PATH)
# Out:
# gcr.io/kubeflow-245520/kfapp2-train:1565117819

# %%
# %%capture
# !git clone https://github.com/kubeflow/examples.git
# !docker build -f examples/mnist/Dockerfile.model -t $TRAIN_IMG_PATH examples/mnist
# !gcloud auth configure-docker --quiet
# !docker push $TRAIN_IMG_PATH

# %% [markdown]
# You should then be able to see the image in the Image Registry in gcloud at
#
# ```https://console.cloud.google.com/gcr/images/<PROJECT>```

# %% [markdown]
# # STEP 6: Create the training job and run it on the cluster

# %% [markdown]
# First we cd into the directory with the configuration files for training and use kustomize to make some edits:

# %%
# %cd examples/mnist/training/GCS
# !kustomize edit add configmap mnist-map-training --from-literal=secretName=user-gcp-sa
# !kustomize edit add configmap mnist-map-training --from-literal=secretMountPath=/var/secrets
# !kustomize edit add configmap mnist-map-training --from-literal=GOOGLE_APPLICATION_CREDENTIALS=/var/secrets/user-gcp-sa.json
# Out:
# [Errno 2] No such file or directory: 'examples/mnist/training/GCS'
# /Users/fieldcady/Desktop/kube/examples/mnist/training/GCS/examples/mnist/training/GCS/examples/mnist/training/GCS
# Error: cannot add key secretName, another key by that name already exists: map[GOOGLE_APPLICATION_CREDENTIALS:/var/secrets/user-gcp-sa.json secretMountPath:/var/secrets secretName:user-gcp-sa]
# Usage:
#   kustomize edit add configmap NAME [--from-file=[key=]source] [--from-literal=key1=value1] [flags]
#
# Examples:
#
# 	# Adds a configmap to the kustomization file (with a specified key)
# 	kustomize edit add configmap my-configmap --from-file=my-key=file/path --from-literal=my-literal=12345
#
# 	# Adds a configmap to the kustomization file (key is the filename)
# 	kustomize edit add configmap my-configmap --from-file=file/path
#
# 	# Adds a configmap from env-file
# 	kustomize edit add configmap my-configmap --from-env-file=env/path.env
#
#
# Flags:
#       --from-env-file string       Specify the path to a file to read lines of key=val pairs to create a configmap (i.e. a Docker .env file).
#       --from-file strings          Key file can be specified using its file path, in which case file basename will be used as configmap key, or optionally with a key and file path, in which case the given key will be used.  Specifying a directory will iterate each named file in the directory whose basename is a valid configmap key.
#       --from-literal stringArray   Specify a key and literal value to insert in configmap (i.e. mykey=somevalue)
#   -h, --help                       help for configmap
#
# Global Flags:
#       --test.bench regexp               run only benchmarks matching regexp
#       --test.benchmem                   print memory allocations for benchmarks
#       --test.benchtime d                run each benchmark for duration d (default 1s)
#       --test.blockprofile file          write a goroutine blocking profile to file
#       --test.blockprofilerate rate      set blocking profile rate (see runtime.SetBlockProfileRate) (default 1)
#       --test.count n                    run tests and benchmarks n times (default 1)
#       --test.coverprofile file          write a coverage profile to file
#       --test.cpu list                   comma-separated list of cpu counts to run each test with
#       --test.cpuprofile file            write a cpu profile to file
#       --test.failfast                   do not start new tests after the first test failure
#       --test.list regexp                list tests, examples, and benchmarks matching regexp then exit
#       --test.memprofile file            write an allocation profile to file
#       --test.memprofilerate rate        set memory allocation profiling rate (see runtime.MemProfileRate)
#       --test.mutexprofile string        write a mutex contention profile to the named file after execution
#       --test.mutexprofilefraction int   if >= 0, calls runtime.SetMutexProfileFraction() (default 1)
#       --test.outputdir dir              write profiles to dir
#       --test.parallel n                 run at most n tests in parallel (default 12)
#       --test.run regexp                 run only tests and examples matching regexp
#       --test.short                      run smaller test suite to save time
#       --test.testlogfile file           write test action log to file (for use only by cmd/go)
#       --test.timeout d                  panic test binary after duration d (default 0, timeout disabled) (default 0s)
#       --test.trace file                 write an execution trace to file
#       --test.v                          verbose: print additional output
#
# Error: cannot add key secretMountPath, another key by that name already exists: map[GOOGLE_APPLICATION_CREDENTIALS:/var/secrets/user-gcp-sa.json secretMountPath:/var/secrets secretName:user-gcp-sa]
# Usage:
#   kustomize edit add configmap NAME [--from-file=[key=]source] [--from-literal=key1=value1] [flags]
#
# Examples:
#
# 	# Adds a configmap to the kustomization file (with a specified key)
# 	kustomize edit add configmap my-configmap --from-file=my-key=file/path --from-literal=my-literal=12345
#
# 	# Adds a configmap to the kustomization file (key is the filename)
# 	kustomize edit add configmap my-configmap --from-file=file/path
#
# 	# Adds a configmap from env-file
# 	kustomize edit add configmap my-configmap --from-env-file=env/path.env
#
#
# Flags:
#       --from-env-file string       Specify the path to a file to read lines of key=val pairs to create a configmap (i.e. a Docker .env file).
#       --from-file strings          Key file can be specified using its file path, in which case file basename will be used as configmap key, or optionally with a key and file path, in which case the given key will be used.  Specifying a directory will iterate each named file in the directory whose basename is a valid configmap key.
#       --from-literal stringArray   Specify a key and literal value to insert in configmap (i.e. mykey=somevalue)
#   -h, --help                       help for configmap
#
# Global Flags:
#       --test.bench regexp               run only benchmarks matching regexp
#       --test.benchmem                   print memory allocations for benchmarks
#       --test.benchtime d                run each benchmark for duration d (default 1s)
#       --test.blockprofile file          write a goroutine blocking profile to file
#       --test.blockprofilerate rate      set blocking profile rate (see runtime.SetBlockProfileRate) (default 1)
#       --test.count n                    run tests and benchmarks n times (default 1)
#       --test.coverprofile file          write a coverage profile to file
#       --test.cpu list                   comma-separated list of cpu counts to run each test with
#       --test.cpuprofile file            write a cpu profile to file
#       --test.failfast                   do not start new tests after the first test failure
#       --test.list regexp                list tests, examples, and benchmarks matching regexp then exit
#       --test.memprofile file            write an allocation profile to file
#       --test.memprofilerate rate        set memory allocation profiling rate (see runtime.MemProfileRate)
#       --test.mutexprofile string        write a mutex contention profile to the named file after execution
#       --test.mutexprofilefraction int   if >= 0, calls runtime.SetMutexProfileFraction() (default 1)
#       --test.outputdir dir              write profiles to dir
#       --test.parallel n                 run at most n tests in parallel (default 12)
#       --test.run regexp                 run only tests and examples matching regexp
#       --test.short                      run smaller test suite to save time
#       --test.testlogfile file           write test action log to file (for use only by cmd/go)
#       --test.timeout d                  panic test binary after duration d (default 0, timeout disabled) (default 0s)
#       --test.trace file                 write an execution trace to file
#       --test.v                          verbose: print additional output
#
# Error: cannot add key GOOGLE_APPLICATION_CREDENTIALS, another key by that name already exists: map[GOOGLE_APPLICATION_CREDENTIALS:/var/secrets/user-gcp-sa.json secretMountPath:/var/secrets secretName:user-gcp-sa]
# Usage:
#   kustomize edit add configmap NAME [--from-file=[key=]source] [--from-literal=key1=value1] [flags]
#
# Examples:
#
# 	# Adds a configmap to the kustomization file (with a specified key)
# 	kustomize edit add configmap my-configmap --from-file=my-key=file/path --from-literal=my-literal=12345
#
# 	# Adds a configmap to the kustomization file (key is the filename)
# 	kustomize edit add configmap my-configmap --from-file=file/path
#
# 	# Adds a configmap from env-file
# 	kustomize edit add configmap my-configmap --from-env-file=env/path.env
#
#
# Flags:
#       --from-env-file string       Specify the path to a file to read lines of key=val pairs to create a configmap (i.e. a Docker .env file).
#       --from-file strings          Key file can be specified using its file path, in which case file basename will be used as configmap key, or optionally with a key and file path, in which case the given key will be used.  Specifying a directory will iterate each named file in the directory whose basename is a valid configmap key.
#       --from-literal stringArray   Specify a key and literal value to insert in configmap (i.e. mykey=somevalue)
#   -h, --help                       help for configmap
#
# Global Flags:
#       --test.bench regexp               run only benchmarks matching regexp
#       --test.benchmem                   print memory allocations for benchmarks
#       --test.benchtime d                run each benchmark for duration d (default 1s)
#       --test.blockprofile file          write a goroutine blocking profile to file
#       --test.blockprofilerate rate      set blocking profile rate (see runtime.SetBlockProfileRate) (default 1)
#       --test.count n                    run tests and benchmarks n times (default 1)
#       --test.coverprofile file          write a coverage profile to file
#       --test.cpu list                   comma-separated list of cpu counts to run each test with
#       --test.cpuprofile file            write a cpu profile to file
#       --test.failfast                   do not start new tests after the first test failure
#       --test.list regexp                list tests, examples, and benchmarks matching regexp then exit
#       --test.memprofile file            write an allocation profile to file
#       --test.memprofilerate rate        set memory allocation profiling rate (see runtime.MemProfileRate)
#       --test.mutexprofile string        write a mutex contention profile to the named file after execution
#       --test.mutexprofilefraction int   if >= 0, calls runtime.SetMutexProfileFraction() (default 1)
#       --test.outputdir dir              write profiles to dir
#       --test.parallel n                 run at most n tests in parallel (default 12)
#       --test.run regexp                 run only tests and examples matching regexp
#       --test.short                      run smaller test suite to save time
#       --test.testlogfile file           write test action log to file (for use only by cmd/go)
#       --test.timeout d                  panic test binary after duration d (default 0, timeout disabled) (default 0s)
#       --test.trace file                 write an execution trace to file
#       --test.v                          verbose: print additional output

# %% [markdown]
# At this point we **should** be one command away from launching the training job on our Kubeflow cluster.
#
# Alas, Kubeflow is an early-stage open-source project, and that means some rough edges.  In this case there are bugs that improperly handle the example configuration files, and we will need to edit them ourselves.  The two files that need editing are kustomization.yaml in the current directory ("main file") and kustomization.yaml in the base directory ("base file").  The changes that need to be made are:
# * In the main file the file Chief_patch.yaml gets added as a path.  But it needs a namespace associated with it that matches the one in the base file.  Do that by adding “namespace: kubeflow” to the properties underneath it.
# * The main and base files both have a "vars:" section that defines some properties.  Move all of the properties in the base file to the main file, deleting that section in the base file.
#
# For simplicity, the next cell will write versions of these files with those changes already made:

# %%
# !git checkout ../base/kustomization.yaml
# !git checkout kustomization.yaml

# %%
base_file = """apiVersion: kustomize.config.k8s.io/v1beta1
kind: Kustomization

resources:
- Chief.yaml

namespace: kubeflow

generatorOptions:
  disableNameSuffixHash: true

configurations:
- params.yaml
"""

main_file = f"""apiVersion: kustomize.config.k8s.io/v1beta1
kind: Kustomization


configurations:
- params.yaml

# TBD (jinchihe) Need move the image to base file once.
# the issue addressed: kubernetes-sigs/kustomize/issues/1040
# TBD (jinchihe) Need to update the image once
# the issue addressed: kubeflow/testing/issues/373
images:
- name: training-image
  newName: {TRAIN_IMG_PATH}

vars:
- fieldref:
    fieldPath: data.name
  name: trainingName
  objref:
    apiVersion: v1
    kind: ConfigMap
    name: mnist-map-training
- fieldref:
    fieldPath: data.modelDir
  name: modelDir
  objref:
    apiVersion: v1
    kind: ConfigMap
    name: mnist-map-training
- fieldref:
    fieldPath: data.exportDir
  name: exportDir
  objref:
    apiVersion: v1
    kind: ConfigMap
    name: mnist-map-training
- fieldref:
    fieldPath: data.trainSteps
  name: trainSteps
  objref:
    apiVersion: v1
    kind: ConfigMap
    name: mnist-map-training
- fieldref:
    fieldPath: data.batchSize
  name: batchSize
  objref:
    apiVersion: v1
    kind: ConfigMap
    name: mnist-map-training
- fieldref:
    fieldPath: data.learningRate
  name: learningRate
  objref:
    apiVersion: v1
    kind: ConfigMap
    name: mnist-map-training
- fieldref:
    fieldPath: data.GOOGLE_APPLICATION_CREDENTIALS
  name: GOOGLE_APPLICATION_CREDENTIALS
  objref:
    apiVersion: v1
    kind: ConfigMap
    name: mnist-map-training
- fieldref:
    fieldPath: data.secretName
  name: secretName
  objref:
    apiVersion: v1
    kind: ConfigMap
    name: mnist-map-training
- fieldref:
    fieldPath: data.secretMountPath
  name: secretMountPath
  objref:
    apiVersion: v1
    kind: ConfigMap
    name: mnist-map-training

patchesJson6902:
- path: Chief_patch.yaml
  target:
    group: kubeflow.org
    kind: TFJob
    name: $(trainingName)
    namespace: kubeflow
    version: v1beta2
resources:
- ../base
configMapGenerator:
- literals:
  - name=mnist-train-dist4
  - trainSteps=20000
  - batchSize=1000
  - learningRate=0.01
  - secretName=user-gcp-sa
  - secretMountPath=/var/secrets
  - GOOGLE_APPLICATION_CREDENTIALS=/var/secrets/user-gcp-sa.json
  - modelDir=gs://{BUCKET_NAME}/
  - exportDir=gs://{BUCKET_NAME}/export
  name: mnist-map-training
"""

_=open('../base/kustomization.yaml', 'w').write(base_file)
_=open('kustomization.yaml', 'w').write(main_file)

# %% [markdown]
# Note the name=mnist-train-dist line in the YAML file.  You will have to choose a new name every
# time you re-kick-off the training job - otherwise the workflow will not get created.  Now we can kick off the job with this command:

# %%
# !kustomize build . | kubectl apply -f -
# Out:
# configmap "mnist-map-training-cd2h45k8dm" created
# tfjob.kubeflow.org "mnist-train-dist4" created

# %% [markdown]
# You can monitor the workflow on the [Google Worklow Page](https://console.cloud.google.com/kubernetes/workload), where you should see a workflow like "mnist-train-dist-chief-0".  **Wait for it to finish.**  After it finishes running then you can copy the exported model file (which is a SavedModel in Tensorflow) to your local machine and zip it up for transfer to Algorithmia.

# %%
# Copy trained model to local space
# !gsutil cp -r gs://$BUCKET_NAME/export .
# Make model/ directory, deleting if it already exists
# !rm -rf model*
# !mkdir model
# Compress the trained model into a ZIP file
# NOTE: this expects there to be only one model in yoru export/ folder
# !cp -r export/$(ls export)/* model/
# !zip model.zip -r model
# Out:
# Copying gs://kubeflow-245520-kfapp2-bucket/export/1565120279/saved_model.pb...
# / [1 files][ 31.0 KiB/ 31.0 KiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying gs://kubeflow-245520-kfapp2-bucket/export/1565120279/variables/variables.data-00000-of-00001...
# Copying gs://kubeflow-245520-kfapp2-bucket/export/1565120279/variables/variables.index...
# \ [3 files][ 12.5 MiB/ 12.5 MiB]
# Operation completed over 3 objects/12.5 MiB.
# /Users/fieldcady/Desktop/kube/examples/mnist/training/GCS/examples/mnist/training/GCS/examples/mnist/training/GCS
# 1565120279
# Chief_patch.yaml   Worker_patch.yaml  kustomization.yaml params.yaml
# Ps_patch.yaml      export             model
#   adding: model/ (stored 0%)
#   adding: model/variables/ (stored 0%)
#   adding: model/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: model/variables/variables.index (deflated 33%)
#   adding: model/saved_model.pb (deflated 83%)

# %% [markdown]
# # STEP 7: Loading Model to Algorithmia and Creating an Algorithm

# %%
# %%capture
# Put zipped model into Algorithmia
# !algo rm .my/kubeflow_example force=true
# !algo mkdir .my/kubeflow_example
# !algo cp model.zip data://.my/kubeflow_example
# Out:
# /Users/fieldcady/Desktop/kube
# 1564596983
# Untitled.ipynb                kfctl_v0.5.1_darwin.tar.gz.2
# bar.txt                       kfctl_v0.5.1_darwin.tar.gz.3
# deployment                    kfctl_v0.5.1_darwin.tar.gz.4
# download.sh                   ks_0.11.0_darwin_amd64
# export                        ks_0.11.0_darwin_amd64.tar.gz
# foo                           kubeflow
# foo.jpg                       kubeflow.ipynb
# foo.txt                       localapp
# kfapp2                        model
# kfctl                         scripts
# kfctl_v0.5.1_darwin.tar.gz    setup-minikube.sh
# kfctl_v0.5.1_darwin.tar.gz.1
#   adding: model/ (stored 0%)
#   adding: model/variables/ (stored 0%)
#   adding: model/variables/variables.data-00000-of-00001 (deflated 8%)
#   adding: model/variables/variables.index (deflated 33%)
#   adding: model/saved_model.pb (deflated 83%)
# Invalid arguments.
#
# Usage:
#   algo rm <data-file>
# Error creating directory: API error - Collection already exists
#   caused by: API error - 400 Bad Request
# Uploaded data://.my/kubeflow_example/model.zip
# Finished uploading 1 file(s)
# model.zip

# %% [markdown]
# Then go to [Algorithmia](http://www.algorithmia.com), create a new algorithm (**making sure to give it internet access** for this tutorial), and set its name as a variable:

# %%
ALGORITHMIA_USERNAME='fcady'
ALGORITHM_NAME="foo"

FILE_TO_WRITE=ALGORITHM_NAME+'/src/'+ALGORITHM_NAME+'.py'
FILE_TO_COMMIT='src/'+ALGORITHM_NAME+'.py'
REPO_TO_CLONE=ALGORITHMIA_USERNAME+'/'+ALGORITHM_NAME

# %% [markdown]
# Now let's use git to checkout this algorithm, write some example code that uses out model, and push it:

# %%
# !rm -rf $ALGORITHM_NAME  # Delete previously downloaded clone, if it exists
# !algo clone $REPO_TO_CLONE
# Out:
# Cloning https://git.algorithmia.com/git/fcady/foo.git
# Cloning into 'foo'...
# remote: Counting objects: 255, done
# remote: Finding sources: 100% (255/255)
# remote: Getting sizes: 100% (55/55)
# remote: Total 255 (delta 138), reused 255 (delta 138)
# Receiving objects: 100% (255/255), 11.58 MiB | 9.22 MiB/s, done.
# Resolving deltas: 100% (138/138), done.
# /Users/fieldcady/Desktop/kube/foo
# Already up to date.
# /Users/fieldcady/Desktop/kube

# %%
# %%writefile $FILE_TO_WRITE
# import Algorithmia
# import tensorflow as tf
# import requests, zipfile
# from os import mkdir, listdir
#
# IMAGE_FNAME  = '/tmp/foo.png'
#
# client = Algorithmia.client()
#
# def extract_model():
#     filename = "data://.my/kubeflow_example/model.zip"
#     input_zip = client.file(filename).getFile().name
#     mkdir("/tmp/unzipped_files")
#     zipped_file = zipfile.ZipFile(input_zip)
#     return zipped_file.extractall("/tmp/unzipped_files")
#
# def download_image(url):
#     with open(IMAGE_FNAME, 'wb') as f:
#         f.write(requests.get(url).content)
#
# def create_session(path_to_graph = "/tmp/unzipped_files/model"):
#     session = tf.Session()
#     tf.saved_model.loader.load(session, ['serve'], path_to_graph)
#     y = session.graph.get_tensor_by_name('Softmax:0')
#     x = session.graph.get_tensor_by_name('Placeholder:0')
#     return (y, x, session)
#
# extract_model()
# Y, X, SESSION = create_session()
#
# def classify_image():
#     img = tf.keras.preprocessing.image.load_img(IMAGE_FNAME).resize((28,28))
#     x = tf.keras.preprocessing.image.img_to_array(img)
#     xx = x.mean(axis=2).reshape((1,28,28)) / 255
#     predict_values = tf.argmax(Y, 1)
#     ret = predict_values.eval(session=SESSION,feed_dict={X: xx})
#     return int(ret)
#
# def apply(input):
#     try:
#         download_image(input['url'])
#         msg = 'downloaded image'
#     except Exception as e:
#         msg = 'failed to get image:' + str(e)
#     try: label = classify_image()
#     except Exception as e:
#         label = str(e)
#     output = {
#         'label': label,
#         'msg': msg
#     }
#     return output
# Out:
# Overwriting foo/src/foo.py

# %%
# %%capture
# %cd $ALGORITHM_NAME
# !git commit -a -m "Code for the algorithm, from Jupyter"
# %cd ..
# %cd $ALGORITHM_NAME
# !git commit -a -m "Code for the algorithm, from Jupyter"
# %cd ..
# Out:
# /Users/fieldcady/Desktop/kube/foo
# [master e45bdd3] Code for the algorithm, from Jupyter
#  Committer: field-cady <fieldcady@Fields-MacBook-Pro.local>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly:
#
#     git config --global user.name "Your Name"
#     git config --global user.email you@example.com
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  1 file changed, 4 insertions(+), 1 deletion(-)
# /Users/fieldcady/Desktop/kube
# /Users/fieldcady/Desktop/kube/foo
# On branch master
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# /Users/fieldcady/Desktop/kube

# %%
# Occassionally you have to run this twice...
# %cd $ALGORITHM_NAME
# !git push
# %cd ..
# Out:
# /Users/fieldcady/Desktop/kube/foo
# Everything up-to-date
# /Users/fieldcady/Desktop/kube

# %% [markdown]
# Now let's build the algorithm!

# %%
import Algorithmia, os
api_key = os.environ['ALGORITHMIA_API_KEY']
client = Algorithmia.client(api_key)
client.algo(algo_namespace).compile()
client.algo(algo_namespace).publish()
# Out:
# {'compilation': {'output': None, 'successful': True},
#  'details': {'label': 'foo', 'summary': None, 'tagline': 'bar'},
#  'name': 'foo',
#  'resource_type': 'algorithm',
#  'self_link': None,
#  'settings': {'algorithm_callability': 'private',
#               'environment': None,
#               'language': None,
#               'license': 'apl',
#               'network_access': 'full',
#               'package_set': 'tensorflow-gpu-1.12',
#               'pipeline_enabled': False,
#               'royalty_microcredits': 0,
#               'source_visibility': 'open'},
#  'version_info': {'git_hash': 'dcf13b8bfe2b363f1ab9281d76ce81ad0bd7f2a4',
#                   'release_notes': None,
#                   'sample_input': None,
#                   'sample_output': None,
#                   'semantic_version': '1.0.6'}}

# %%
algo_namespace = "{}/{}".format(ALGORITHMIA_USERNAME, ALGORITHM_NAME)
latest_hash = client.algo(algo_namespace).info().version_info.git_hash
algo_input = {
    #"url": "https://edwin-de-jong.github.io/blog/mnist-sequence-data/fig/5.png"
    "url": "https://miro.medium.com/max/490/1*nlfLUgHUEj5vW7WVJpxY-g.png"
}
res = client.algo(algo_namespace+'/'+latest_hash).pipe(algo_input).result
print(res)
# Out:
# {'/tmp/': ['tmp5b0b4olo', 'algoout', 'unzipped_files', '.X11-unix', 'foo.png'], '/tmp/unzipped_files/model/': ['variables', 'saved_model.pb'], 'label': 0, 'msg': 'downloaded_fine', 'status': 'extracted,created,downloaded,labelled'}
